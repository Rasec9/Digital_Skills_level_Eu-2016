# %%
import tsv_to_pandas

# %%
import urllib.request
import gzip

eurostat_link = "http://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=data%2Fisoc_sk_dskl_i.tsv.gz"
urllib.request.urlretrieve(eurostat_link , "isoc_sk_dskl_i.tsv.gz")
# Out:
# ('isoc_sk_dskl_i.tsv.gz', <http.client.HTTPMessage at 0x7fad4a7657b8>)

# %%
d_skills = tsv_to_pandas.tsv_to_dataframe_long('isoc_sk_dskl_i.tsv.gz')
d_skills
# Out:
#        var_indic_is var_ind_type    var_unit var_geo variable  value  \
# 0          I_DSK_AB    CB_EU_FOR      PC_IND      AT     2017   45.0
# 1          I_DSK_AB    CB_EU_FOR      PC_IND      BE     2017   33.0
# 2          I_DSK_AB    CB_EU_FOR      PC_IND      BG     2017   30.0
# 3          I_DSK_AB    CB_EU_FOR      PC_IND      CH     2017   43.0
# 4          I_DSK_AB    CB_EU_FOR      PC_IND      CY     2017   17.0
# 5          I_DSK_AB    CB_EU_FOR      PC_IND      CZ     2017   30.0
# 6          I_DSK_AB    CB_EU_FOR      PC_IND      DE     2017   28.0
# 7          I_DSK_AB    CB_EU_FOR      PC_IND      DK     2017   39.0
# 8          I_DSK_AB    CB_EU_FOR      PC_IND      EA     2017   27.0
# 9          I_DSK_AB    CB_EU_FOR      PC_IND      EE     2017   31.0
# 10         I_DSK_AB    CB_EU_FOR      PC_IND      EL     2017   29.0
# 11         I_DSK_AB    CB_EU_FOR      PC_IND      ES     2017   29.0
# 12         I_DSK_AB    CB_EU_FOR      PC_IND    EU15     2017   29.0
# 13         I_DSK_AB    CB_EU_FOR      PC_IND    EU27     2017   29.0
# 14         I_DSK_AB    CB_EU_FOR      PC_IND    EU28     2017   29.0
# 15         I_DSK_AB    CB_EU_FOR      PC_IND      FI     2017   26.0
# 16         I_DSK_AB    CB_EU_FOR      PC_IND      FR     2017   17.0
# 17         I_DSK_AB    CB_EU_FOR      PC_IND      HR     2017   16.0
# 18         I_DSK_AB    CB_EU_FOR      PC_IND      HU     2017   17.0
# 19         I_DSK_AB    CB_EU_FOR      PC_IND      IE     2017   30.0
# 20         I_DSK_AB    CB_EU_FOR      PC_IND      IS     2017   56.0
# 21         I_DSK_AB    CB_EU_FOR      PC_IND      IT     2017    NaN
# 22         I_DSK_AB    CB_EU_FOR      PC_IND      LT     2017   23.0
# 23         I_DSK_AB    CB_EU_FOR      PC_IND      LU     2017   48.0
# 24         I_DSK_AB    CB_EU_FOR      PC_IND      LV     2017   15.0
# 25         I_DSK_AB    CB_EU_FOR      PC_IND      MK     2017    NaN
# 26         I_DSK_AB    CB_EU_FOR      PC_IND      MT     2017   63.0
# 27         I_DSK_AB    CB_EU_FOR      PC_IND      NL     2017   60.0
# 28         I_DSK_AB    CB_EU_FOR      PC_IND      NO     2017   47.0
# 29         I_DSK_AB    CB_EU_FOR      PC_IND      PL     2017    NaN
# ...             ...          ...         ...     ...      ...    ...
# 290034      I_DSK_X       Y65_74  PC_IND_IU3      IE     2015    3.0
# 290035      I_DSK_X       Y65_74  PC_IND_IU3      IS     2015    NaN
# 290036      I_DSK_X       Y65_74  PC_IND_IU3      IT     2015    5.0
# 290037      I_DSK_X       Y65_74  PC_IND_IU3      LT     2015    2.0
# 290038      I_DSK_X       Y65_74  PC_IND_IU3      LU     2015    2.0
# 290039      I_DSK_X       Y65_74  PC_IND_IU3      LV     2015    3.0
# 290040      I_DSK_X       Y65_74  PC_IND_IU3      MK     2015    0.0
# 290041      I_DSK_X       Y65_74  PC_IND_IU3      MT     2015    4.0
# 290042      I_DSK_X       Y65_74  PC_IND_IU3      NL     2015    1.0
# 290043      I_DSK_X       Y65_74  PC_IND_IU3      NO     2015    1.0
# 290044      I_DSK_X       Y65_74  PC_IND_IU3      PL     2015    5.0
# 290045      I_DSK_X       Y65_74  PC_IND_IU3      PT     2015    7.0
# 290046      I_DSK_X       Y65_74  PC_IND_IU3      RO     2015    NaN
# 290047      I_DSK_X       Y65_74  PC_IND_IU3      RS     2015    3.0
# 290048      I_DSK_X       Y65_74  PC_IND_IU3      SE     2015    2.0
# 290049      I_DSK_X       Y65_74  PC_IND_IU3      SI     2015    3.0
# 290050      I_DSK_X       Y65_74  PC_IND_IU3      SK     2015    0.0
# 290051      I_DSK_X       Y65_74  PC_IND_IU3      TR     2015    5.0
# 290052      I_DSK_X       Y65_74  PC_IND_IU3      UK     2015    1.0
# 290053      I_DSK_X      Y75_MAX      PC_IND      CZ     2015    0.0
# 290054      I_DSK_X      Y75_MAX      PC_IND      ES     2015    1.0
# 290055      I_DSK_X      Y75_MAX      PC_IND      IT     2015    0.0
# 290056      I_DSK_X      Y75_MAX      PC_IND      MK     2015    NaN
# 290057      I_DSK_X      Y75_MAX      PC_IND      NO     2015    5.0
# 290058      I_DSK_X      Y75_MAX      PC_IND      SK     2015    0.0
# 290059      I_DSK_X      Y75_MAX  PC_IND_IU3      CZ     2015    4.0
# 290060      I_DSK_X      Y75_MAX  PC_IND_IU3      ES     2015    9.0
# 290061      I_DSK_X      Y75_MAX  PC_IND_IU3      IT     2015    7.0
# 290062      I_DSK_X      Y75_MAX  PC_IND_IU3      NO     2015    8.0
# 290063      I_DSK_X      Y75_MAX  PC_IND_IU3      SK     2015    0.0
#
#        value_raw eurostat_annotation
# 0            45
# 1            33
# 2           30 u                   u
# 3           43 b                   b
# 4            17
# 5            30
# 6            28
# 7            39
# 8            27
# 9           31 u                   u
# 10           29
# 11           29
# 12           29
# 13           29
# 14           29
# 15          26 u                   u
# 16           17
# 17           16
# 18           17
# 19           30
# 20           56
# 21           : u                   u
# 22          23 u                   u
# 23           48
# 24           15
# 25           : u                   u
# 26          63 u                   u
# 27           60
# 28           47
# 29           : u                   u
# ...          ...                 ...
# 290034        3
# 290035        :
# 290036        5
# 290037        2
# 290038        2
# 290039        3
# 290040        0
# 290041        4
# 290042        1
# 290043        1
# 290044        5
# 290045        7
# 290046        :
# 290047        3
# 290048        2
# 290049        3
# 290050       0 n                   n
# 290051        5
# 290052        1
# 290053       0 n                   n
# 290054        1
# 290055       0 n                   n
# 290056        :
# 290057       5 u                   u
# 290058        0
# 290059        4
# 290060        9
# 290061        7
# 290062       8 u                   u
# 290063       0 u                   u
#
# [290064 rows x 8 columns]

# %%
#Importiamo pandas e numpy
import pandas as pd
import numpy as np

# %%
#creiamo una lista che contenga le etichette che corrispondono ai quattro livelli di digital skills e il livello nullo
skill_levels = ['I_DSK_NA', 'I_DSK_X', 'I_DSK_L', 'I_DSK_B', 'I_DSK_AB']

# %%
#chiedo attraverso .loc di localizzare le righe dove, nella colonna var_indic_is, sono presenti le etichette che ci servono
d_skills.loc[d_skills['var_indic_is'].isin(skill_levels)]
# Out:
#        var_indic_is var_ind_type    var_unit var_geo variable  value  \
# 0          I_DSK_AB    CB_EU_FOR      PC_IND      AT     2017   45.0
# 1          I_DSK_AB    CB_EU_FOR      PC_IND      BE     2017   33.0
# 2          I_DSK_AB    CB_EU_FOR      PC_IND      BG     2017   30.0
# 3          I_DSK_AB    CB_EU_FOR      PC_IND      CH     2017   43.0
# 4          I_DSK_AB    CB_EU_FOR      PC_IND      CY     2017   17.0
# 5          I_DSK_AB    CB_EU_FOR      PC_IND      CZ     2017   30.0
# 6          I_DSK_AB    CB_EU_FOR      PC_IND      DE     2017   28.0
# 7          I_DSK_AB    CB_EU_FOR      PC_IND      DK     2017   39.0
# 8          I_DSK_AB    CB_EU_FOR      PC_IND      EA     2017   27.0
# 9          I_DSK_AB    CB_EU_FOR      PC_IND      EE     2017   31.0
# 10         I_DSK_AB    CB_EU_FOR      PC_IND      EL     2017   29.0
# 11         I_DSK_AB    CB_EU_FOR      PC_IND      ES     2017   29.0
# 12         I_DSK_AB    CB_EU_FOR      PC_IND    EU15     2017   29.0
# 13         I_DSK_AB    CB_EU_FOR      PC_IND    EU27     2017   29.0
# 14         I_DSK_AB    CB_EU_FOR      PC_IND    EU28     2017   29.0
# 15         I_DSK_AB    CB_EU_FOR      PC_IND      FI     2017   26.0
# 16         I_DSK_AB    CB_EU_FOR      PC_IND      FR     2017   17.0
# 17         I_DSK_AB    CB_EU_FOR      PC_IND      HR     2017   16.0
# 18         I_DSK_AB    CB_EU_FOR      PC_IND      HU     2017   17.0
# 19         I_DSK_AB    CB_EU_FOR      PC_IND      IE     2017   30.0
# 20         I_DSK_AB    CB_EU_FOR      PC_IND      IS     2017   56.0
# 21         I_DSK_AB    CB_EU_FOR      PC_IND      IT     2017    NaN
# 22         I_DSK_AB    CB_EU_FOR      PC_IND      LT     2017   23.0
# 23         I_DSK_AB    CB_EU_FOR      PC_IND      LU     2017   48.0
# 24         I_DSK_AB    CB_EU_FOR      PC_IND      LV     2017   15.0
# 25         I_DSK_AB    CB_EU_FOR      PC_IND      MK     2017    NaN
# 26         I_DSK_AB    CB_EU_FOR      PC_IND      MT     2017   63.0
# 27         I_DSK_AB    CB_EU_FOR      PC_IND      NL     2017   60.0
# 28         I_DSK_AB    CB_EU_FOR      PC_IND      NO     2017   47.0
# 29         I_DSK_AB    CB_EU_FOR      PC_IND      PL     2017    NaN
# ...             ...          ...         ...     ...      ...    ...
# 290034      I_DSK_X       Y65_74  PC_IND_IU3      IE     2015    3.0
# 290035      I_DSK_X       Y65_74  PC_IND_IU3      IS     2015    NaN
# 290036      I_DSK_X       Y65_74  PC_IND_IU3      IT     2015    5.0
# 290037      I_DSK_X       Y65_74  PC_IND_IU3      LT     2015    2.0
# 290038      I_DSK_X       Y65_74  PC_IND_IU3      LU     2015    2.0
# 290039      I_DSK_X       Y65_74  PC_IND_IU3      LV     2015    3.0
# 290040      I_DSK_X       Y65_74  PC_IND_IU3      MK     2015    0.0
# 290041      I_DSK_X       Y65_74  PC_IND_IU3      MT     2015    4.0
# 290042      I_DSK_X       Y65_74  PC_IND_IU3      NL     2015    1.0
# 290043      I_DSK_X       Y65_74  PC_IND_IU3      NO     2015    1.0
# 290044      I_DSK_X       Y65_74  PC_IND_IU3      PL     2015    5.0
# 290045      I_DSK_X       Y65_74  PC_IND_IU3      PT     2015    7.0
# 290046      I_DSK_X       Y65_74  PC_IND_IU3      RO     2015    NaN
# 290047      I_DSK_X       Y65_74  PC_IND_IU3      RS     2015    3.0
# 290048      I_DSK_X       Y65_74  PC_IND_IU3      SE     2015    2.0
# 290049      I_DSK_X       Y65_74  PC_IND_IU3      SI     2015    3.0
# 290050      I_DSK_X       Y65_74  PC_IND_IU3      SK     2015    0.0
# 290051      I_DSK_X       Y65_74  PC_IND_IU3      TR     2015    5.0
# 290052      I_DSK_X       Y65_74  PC_IND_IU3      UK     2015    1.0
# 290053      I_DSK_X      Y75_MAX      PC_IND      CZ     2015    0.0
# 290054      I_DSK_X      Y75_MAX      PC_IND      ES     2015    1.0
# 290055      I_DSK_X      Y75_MAX      PC_IND      IT     2015    0.0
# 290056      I_DSK_X      Y75_MAX      PC_IND      MK     2015    NaN
# 290057      I_DSK_X      Y75_MAX      PC_IND      NO     2015    5.0
# 290058      I_DSK_X      Y75_MAX      PC_IND      SK     2015    0.0
# 290059      I_DSK_X      Y75_MAX  PC_IND_IU3      CZ     2015    4.0
# 290060      I_DSK_X      Y75_MAX  PC_IND_IU3      ES     2015    9.0
# 290061      I_DSK_X      Y75_MAX  PC_IND_IU3      IT     2015    7.0
# 290062      I_DSK_X      Y75_MAX  PC_IND_IU3      NO     2015    8.0
# 290063      I_DSK_X      Y75_MAX  PC_IND_IU3      SK     2015    0.0
#
#        value_raw eurostat_annotation
# 0            45
# 1            33
# 2           30 u                   u
# 3           43 b                   b
# 4            17
# 5            30
# 6            28
# 7            39
# 8            27
# 9           31 u                   u
# 10           29
# 11           29
# 12           29
# 13           29
# 14           29
# 15          26 u                   u
# 16           17
# 17           16
# 18           17
# 19           30
# 20           56
# 21           : u                   u
# 22          23 u                   u
# 23           48
# 24           15
# 25           : u                   u
# 26          63 u                   u
# 27           60
# 28           47
# 29           : u                   u
# ...          ...                 ...
# 290034        3
# 290035        :
# 290036        5
# 290037        2
# 290038        2
# 290039        3
# 290040        0
# 290041        4
# 290042        1
# 290043        1
# 290044        5
# 290045        7
# 290046        :
# 290047        3
# 290048        2
# 290049        3
# 290050       0 n                   n
# 290051        5
# 290052        1
# 290053       0 n                   n
# 290054        1
# 290055       0 n                   n
# 290056        :
# 290057       5 u                   u
# 290058        0
# 290059        4
# 290060        9
# 290061        7
# 290062       8 u                   u
# 290063       0 u                   u
#
# [89730 rows x 8 columns]

# %%
#salvo una copia di backup del database completo
d_skills_backup = d_skills

# %%
#salvo il database d'interesse come d_skills
d_skills = d_skills.loc[d_skills['var_indic_is'].isin(skill_levels)]

# %%
#Adesso salvo come d_skills soltanto la parte della matrice riguardante tutti gli individui.
d_skills = d_skills.loc[d_skills['var_ind_type'] == 'IND_TOTAL']

# %%
#Divido la matrice in due matrici: una con coloro che hanno usato internet negli ultimi 3 mesi, una con tutti.
d_skills_3_months = d_skills.loc[d_skills['var_unit'] == 'PC_IND_IU3']
d_skills_all = d_skills.loc[d_skills['var_unit'] == 'PC_IND']

# %%
#Controllo che nella matrice a 3 mesi non ci siano quelli che non hanno usato internet negli ultimi 3 mesi
d_skills_3_months.loc[d_skills['var_indic_is'] == 'I_DSK_NA']
# Out:
# Empty DataFrame
# Columns: [var_indic_is, var_ind_type, var_unit, var_geo, variable, value, value_raw, eurostat_annotation]
# Index: []

# %%
#Creiamo una lista con le etichette relative ai paesi che ci servono
country_list = ['IT', 'EU28', 'EU15', 'PT', 'DE']

# %%
#Creo una nuova matrice filtrata sulla base delle etichette in country_list. Conterrò solo i valori dei paesi di interesse
country_filter = d_skills_all.loc[d_skills_all['var_geo'].isin(country_list)]
country_filter
# Out:
#        var_indic_is var_ind_type var_unit var_geo variable  value value_raw  \
# 2467       I_DSK_AB    IND_TOTAL   PC_IND      DE     2017   37.0       37
# 2473       I_DSK_AB    IND_TOTAL   PC_IND    EU15     2017   34.0       34
# 2475       I_DSK_AB    IND_TOTAL   PC_IND    EU28     2017   31.0       31
# 2482       I_DSK_AB    IND_TOTAL   PC_IND      IT     2017    NaN       : u
# 2492       I_DSK_AB    IND_TOTAL   PC_IND      PT     2017   31.0       31
# 9145        I_DSK_B    IND_TOTAL   PC_IND      DE     2017   31.0       31
# 9151        I_DSK_B    IND_TOTAL   PC_IND    EU15     2017   26.0       26
# 9153        I_DSK_B    IND_TOTAL   PC_IND    EU28     2017   26.0       26
# 9160        I_DSK_B    IND_TOTAL   PC_IND      IT     2017    NaN       : u
# 9170        I_DSK_B    IND_TOTAL   PC_IND      PT     2017   20.0       20
# 49213       I_DSK_L    IND_TOTAL   PC_IND      DE     2017   22.0       22
# 49219       I_DSK_L    IND_TOTAL   PC_IND    EU15     2017   25.0       25
# 49221       I_DSK_L    IND_TOTAL   PC_IND    EU28     2017   26.0       26
# 49228       I_DSK_L    IND_TOTAL   PC_IND      IT     2017    NaN       : u
# 49238       I_DSK_L    IND_TOTAL   PC_IND      PT     2017   23.0       23
# 54661      I_DSK_NA    IND_TOTAL   PC_IND      DE     2017   10.0       10
# 54667      I_DSK_NA    IND_TOTAL   PC_IND    EU15     2017   14.0       14
# 54669      I_DSK_NA    IND_TOTAL   PC_IND    EU28     2017   16.0       16
# 54676      I_DSK_NA    IND_TOTAL   PC_IND      IT     2017   29.0       29
# 54686      I_DSK_NA    IND_TOTAL   PC_IND      PT     2017   26.0       26
# 92573       I_DSK_X    IND_TOTAL   PC_IND      DE     2017    0.0       0 n
# 92579       I_DSK_X    IND_TOTAL   PC_IND    EU15     2017    1.0        1
# 92581       I_DSK_X    IND_TOTAL   PC_IND    EU28     2017    1.0        1
# 92588       I_DSK_X    IND_TOTAL   PC_IND      IT     2017    NaN       : u
# 92597       I_DSK_X    IND_TOTAL   PC_IND      PT     2017    1.0        1
# 99155      I_DSK_AB    IND_TOTAL   PC_IND      DE     2016   33.0       33
# 99161      I_DSK_AB    IND_TOTAL   PC_IND    EU15     2016   32.0       32
# 99163      I_DSK_AB    IND_TOTAL   PC_IND    EU28     2016   29.0       29
# 99170      I_DSK_AB    IND_TOTAL   PC_IND      IT     2016   19.0       19
# 99180      I_DSK_AB    IND_TOTAL   PC_IND      PT     2016   28.0       28
# ...             ...          ...      ...     ...      ...    ...       ...
# 189261      I_DSK_X    IND_TOTAL   PC_IND      DE     2016    0.0       0 n
# 189267      I_DSK_X    IND_TOTAL   PC_IND    EU15     2016    1.0        1
# 189269      I_DSK_X    IND_TOTAL   PC_IND    EU28     2016    1.0        1
# 189276      I_DSK_X    IND_TOTAL   PC_IND      IT     2016    2.0        2
# 189285      I_DSK_X    IND_TOTAL   PC_IND      PT     2016    1.0        1
# 195843     I_DSK_AB    IND_TOTAL   PC_IND      DE     2015   35.0       35
# 195849     I_DSK_AB    IND_TOTAL   PC_IND    EU15     2015   31.0       31
# 195851     I_DSK_AB    IND_TOTAL   PC_IND    EU28     2015   28.0       28
# 195858     I_DSK_AB    IND_TOTAL   PC_IND      IT     2015   19.0       19
# 195868     I_DSK_AB    IND_TOTAL   PC_IND      PT     2015   28.0       28
# 202521      I_DSK_B    IND_TOTAL   PC_IND      DE     2015   31.0       31
# 202527      I_DSK_B    IND_TOTAL   PC_IND    EU15     2015   28.0       28
# 202529      I_DSK_B    IND_TOTAL   PC_IND    EU28     2015   27.0       27
# 202536      I_DSK_B    IND_TOTAL   PC_IND      IT     2015   24.0       24
# 202546      I_DSK_B    IND_TOTAL   PC_IND      PT     2015   20.0       20
# 242589      I_DSK_L    IND_TOTAL   PC_IND      DE     2015   21.0       21
# 242595      I_DSK_L    IND_TOTAL   PC_IND    EU15     2015   23.0       23
# 242597      I_DSK_L    IND_TOTAL   PC_IND    EU28     2015   23.0       23
# 242604      I_DSK_L    IND_TOTAL   PC_IND      IT     2015   21.0       21
# 242614      I_DSK_L    IND_TOTAL   PC_IND      PT     2015   20.0       20
# 248037     I_DSK_NA    IND_TOTAL   PC_IND      DE     2015   12.0       12
# 248043     I_DSK_NA    IND_TOTAL   PC_IND    EU15     2015   17.0       17
# 248045     I_DSK_NA    IND_TOTAL   PC_IND    EU28     2015   21.0       21
# 248052     I_DSK_NA    IND_TOTAL   PC_IND      IT     2015   34.0       34
# 248062     I_DSK_NA    IND_TOTAL   PC_IND      PT     2015   31.0       31
# 285949      I_DSK_X    IND_TOTAL   PC_IND      DE     2015    0.0       0 n
# 285955      I_DSK_X    IND_TOTAL   PC_IND    EU15     2015    1.0        1
# 285957      I_DSK_X    IND_TOTAL   PC_IND    EU28     2015    1.0        1
# 285964      I_DSK_X    IND_TOTAL   PC_IND      IT     2015    2.0        2
# 285973      I_DSK_X    IND_TOTAL   PC_IND      PT     2015    1.0        1
#
#        eurostat_annotation
# 2467
# 2473
# 2475
# 2482                     u
# 2492
# 9145
# 9151
# 9153
# 9160                     u
# 9170
# 49213
# 49219
# 49221
# 49228                    u
# 49238
# 54661
# 54667
# 54669
# 54676
# 54686
# 92573                    n
# 92579
# 92581
# 92588                    u
# 92597
# 99155
# 99161
# 99163
# 99170
# 99180
# ...                    ...
# 189261                   n
# 189267
# 189269
# 189276
# 189285
# 195843
# 195849
# 195851
# 195858
# 195868
# 202521
# 202527
# 202529
# 202536
# 202546
# 242589
# 242595
# 242597
# 242604
# 242614
# 248037
# 248043
# 248045
# 248052
# 248062
# 285949                   n
# 285955
# 285957
# 285964
# 285973
#
# [75 rows x 8 columns]

# %%
year2016 = country_filter.loc[country_filter['variable'] == 2016]

# %%
year2016
# Out:
#        var_indic_is var_ind_type var_unit var_geo variable  value value_raw  \
# 99155      I_DSK_AB    IND_TOTAL   PC_IND      DE     2016   33.0       33
# 99161      I_DSK_AB    IND_TOTAL   PC_IND    EU15     2016   32.0       32
# 99163      I_DSK_AB    IND_TOTAL   PC_IND    EU28     2016   29.0       29
# 99170      I_DSK_AB    IND_TOTAL   PC_IND      IT     2016   19.0       19
# 99180      I_DSK_AB    IND_TOTAL   PC_IND      PT     2016   28.0       28
# 105833      I_DSK_B    IND_TOTAL   PC_IND      DE     2016   34.0       34
# 105839      I_DSK_B    IND_TOTAL   PC_IND    EU15     2016   28.0       28
# 105841      I_DSK_B    IND_TOTAL   PC_IND    EU28     2016   27.0       27
# 105848      I_DSK_B    IND_TOTAL   PC_IND      IT     2016   24.0       24
# 105858      I_DSK_B    IND_TOTAL   PC_IND      PT     2016   19.0       19
# 145901      I_DSK_L    IND_TOTAL   PC_IND      DE     2016   22.0       22
# 145907      I_DSK_L    IND_TOTAL   PC_IND    EU15     2016   24.0       24
# 145909      I_DSK_L    IND_TOTAL   PC_IND    EU28     2016   25.0       25
# 145916      I_DSK_L    IND_TOTAL   PC_IND      IT     2016   23.0       23
# 145926      I_DSK_L    IND_TOTAL   PC_IND      PT     2016   22.0       22
# 151349     I_DSK_NA    IND_TOTAL   PC_IND      DE     2016   10.0       10
# 151355     I_DSK_NA    IND_TOTAL   PC_IND    EU15     2016   15.0       15
# 151357     I_DSK_NA    IND_TOTAL   PC_IND    EU28     2016   18.0       18
# 151364     I_DSK_NA    IND_TOTAL   PC_IND      IT     2016   31.0       31
# 151374     I_DSK_NA    IND_TOTAL   PC_IND      PT     2016   30.0       30
# 189261      I_DSK_X    IND_TOTAL   PC_IND      DE     2016    0.0       0 n
# 189267      I_DSK_X    IND_TOTAL   PC_IND    EU15     2016    1.0        1
# 189269      I_DSK_X    IND_TOTAL   PC_IND    EU28     2016    1.0        1
# 189276      I_DSK_X    IND_TOTAL   PC_IND      IT     2016    2.0        2
# 189285      I_DSK_X    IND_TOTAL   PC_IND      PT     2016    1.0        1
#
#        eurostat_annotation
# 99155
# 99161
# 99163
# 99170
# 99180
# 105833
# 105839
# 105841
# 105848
# 105858
# 145901
# 145907
# 145909
# 145916
# 145926
# 151349
# 151355
# 151357
# 151364
# 151374
# 189261                   n
# 189267
# 189269
# 189276
# 189285

# %%
#Pulisco la tabella in modo che sia di facile lettura
operational = year2016.filter(['var_indic_is','var_geo','value'], axis=1)

# %%
operational
# Out:
#        var_indic_is var_geo  value
# 99155      I_DSK_AB      DE   33.0
# 99161      I_DSK_AB    EU15   32.0
# 99163      I_DSK_AB    EU28   29.0
# 99170      I_DSK_AB      IT   19.0
# 99180      I_DSK_AB      PT   28.0
# 105833      I_DSK_B      DE   34.0
# 105839      I_DSK_B    EU15   28.0
# 105841      I_DSK_B    EU28   27.0
# 105848      I_DSK_B      IT   24.0
# 105858      I_DSK_B      PT   19.0
# 145901      I_DSK_L      DE   22.0
# 145907      I_DSK_L    EU15   24.0
# 145909      I_DSK_L    EU28   25.0
# 145916      I_DSK_L      IT   23.0
# 145926      I_DSK_L      PT   22.0
# 151349     I_DSK_NA      DE   10.0
# 151355     I_DSK_NA    EU15   15.0
# 151357     I_DSK_NA    EU28   18.0
# 151364     I_DSK_NA      IT   31.0
# 151374     I_DSK_NA      PT   30.0
# 189261      I_DSK_X      DE    0.0
# 189267      I_DSK_X    EU15    1.0
# 189269      I_DSK_X    EU28    1.0
# 189276      I_DSK_X      IT    2.0
# 189285      I_DSK_X      PT    1.0

# %%
#Riordino le colonne
operational = operational[['var_geo', 'var_indic_is', 'value']]

# %%
operational
# Out:
#        var_geo var_indic_is  value
# 99155       DE     I_DSK_AB   33.0
# 99161     EU15     I_DSK_AB   32.0
# 99163     EU28     I_DSK_AB   29.0
# 99170       IT     I_DSK_AB   19.0
# 99180       PT     I_DSK_AB   28.0
# 105833      DE      I_DSK_B   34.0
# 105839    EU15      I_DSK_B   28.0
# 105841    EU28      I_DSK_B   27.0
# 105848      IT      I_DSK_B   24.0
# 105858      PT      I_DSK_B   19.0
# 145901      DE      I_DSK_L   22.0
# 145907    EU15      I_DSK_L   24.0
# 145909    EU28      I_DSK_L   25.0
# 145916      IT      I_DSK_L   23.0
# 145926      PT      I_DSK_L   22.0
# 151349      DE     I_DSK_NA   10.0
# 151355    EU15     I_DSK_NA   15.0
# 151357    EU28     I_DSK_NA   18.0
# 151364      IT     I_DSK_NA   31.0
# 151374      PT     I_DSK_NA   30.0
# 189261      DE      I_DSK_X    0.0
# 189267    EU15      I_DSK_X    1.0
# 189269    EU28      I_DSK_X    1.0
# 189276      IT      I_DSK_X    2.0
# 189285      PT      I_DSK_X    1.0

# %%
#Faccio in modo che gli indici diventino le nazioni
operational.set_index('var_geo', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var_geo'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-35735dffb4de> in <module>()
#       1 #Faccio in modo che gli indici diventino le nazioni
# ----> 2 operational.set_index('var_geo', inplace = True)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3144                 names.append(None)
#    3145             else:
# -> 3146                 level = frame[col]._values
#    3147                 names.append(col)
#    3148                 if drop:
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var_geo'

# %%
#Rinomino le colonne
operational = operational.rename(columns={"var_indic_is": "livello abilità", "value": "%"})

# %%
operational
# Out:
#         livello abilità     %
# var_geo
# DE             I_DSK_AB  33.0
# EU15           I_DSK_AB  32.0
# EU28           I_DSK_AB  29.0
# IT             I_DSK_AB  19.0
# PT             I_DSK_AB  28.0
# DE              I_DSK_B  34.0
# EU15            I_DSK_B  28.0
# EU28            I_DSK_B  27.0
# IT              I_DSK_B  24.0
# PT              I_DSK_B  19.0
# DE              I_DSK_L  22.0
# EU15            I_DSK_L  24.0
# EU28            I_DSK_L  25.0
# IT              I_DSK_L  23.0
# PT              I_DSK_L  22.0
# DE             I_DSK_NA  10.0
# EU15           I_DSK_NA  15.0
# EU28           I_DSK_NA  18.0
# IT             I_DSK_NA  31.0
# PT             I_DSK_NA  30.0
# DE              I_DSK_X   0.0
# EU15            I_DSK_X   1.0
# EU28            I_DSK_X   1.0
# IT              I_DSK_X   2.0
# PT              I_DSK_X   1.0

# %%
#Riordino la tabella e setto alcuni dei valori (il livello delle digital skill) come delle colonne e non più delle righe.
#In questo modo ottengo una matrice "standard"
operational.pivot(columns = 'livello abilità', values='%')
# Out:
# livello abilità  I_DSK_AB  I_DSK_B  I_DSK_L  I_DSK_NA  I_DSK_X
# var_geo
# DE                   33.0     34.0     22.0      10.0      0.0
# EU15                 32.0     28.0     24.0      15.0      1.0
# EU28                 29.0     27.0     25.0      18.0      1.0
# IT                   19.0     24.0     23.0      31.0      2.0
# PT                   28.0     19.0     22.0      30.0      1.0

# %%
#Cambio il nome delle variabili (che ora sono le nostre colonne). Rendo così la tabella leggibile.
#Rinonino di nuovo la tabella sempre operational, così che sostituisca la precedente.
#Perdo la visualizzazione a "tabella classica", no panic, basta richiamare il pivot
operational = operational.replace({'I_DSK_AB': "Above Basic", 'I_DSK_B': "Basic", 'I_DSK_L': "Low", 'I_DSK_X': "No skills", 'I_DSK_NA': "NA"})

# %%
operational.pivot(columns = 'livello abilità', values='%')
# Out:
# livello abilità  Above Basic  Basic   Low    NA  No skills
# var_geo
# DE                      33.0   34.0  22.0  10.0        0.0
# EU15                    32.0   28.0  24.0  15.0        1.0
# EU28                    29.0   27.0  25.0  18.0        1.0
# IT                      19.0   24.0  23.0  31.0        2.0
# PT                      28.0   19.0  22.0  30.0        1.0
